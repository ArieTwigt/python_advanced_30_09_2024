# %%
import pandas as pd
import numpy as np

# %%
# import the csv file
data = pd.read_csv("data/german_data_clean.csv")

# %%
data.shape
# Out:
# (1000, 21)

# %%
data.columns
# Out:
# Index(['checking_account', 'duration_months', 'credit_history', 'purpose',
#        'credit_amount', 'savings', 'present_employment_since',
#        'installment_rate', 'personal_status_sex', 'other_deptors',
#        'present_residence', 'property', 'age_years', 'other_installment_plans',
#        'housing', 'existing_credits', 'job', 'people_liable_maintenance',
#        'telephone', 'foreign_worker', 'response'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   checking_account           1000 non-null   object
#  1   duration_months            1000 non-null   int64
#  2   credit_history             1000 non-null   object
#  3   purpose                    1000 non-null   object
#  4   credit_amount              1000 non-null   int64
#  5   savings                    1000 non-null   object
#  6   present_employment_since   1000 non-null   object
#  7   installment_rate           1000 non-null   int64
#  8   personal_status_sex        1000 non-null   object
#  9   other_deptors              1000 non-null   object
#  10  present_residence          1000 non-null   int64
#  11  property                   1000 non-null   object
#  12  age_years                  1000 non-null   int64
# ...

# %%
# single column
data['age_years']
# Out:
# 0      67
# 1      22
# 2      49
# 3      45
# 4      53
#        ..
# 995    31
# 996    40
# 997    38
# 998    23
# 999    27
# Name: age_years, Length: 1000, dtype: int64

# %%
# multiple columns: age_years, credit_amount, purpose
columns = ['age_years', 'credit_amount', 'purpose']
data[columns]
# Out:
#      age_years  credit_amount              purpose
# 0           67           1169     radio/television
# 1           22           5951     radio/television
# 2           49           2096            education
# 3           45           7882  furniture/equipment
# 4           53           4870            car (new)
# ..         ...            ...                  ...
# 995         31           1736  furniture/equipment
# 996         40           3857           car (used)
# 997         38            804     radio/television
# 998         23           1845     radio/television
# 999         27           4576           car (used)
#
# [1000 rows x 3 columns]

# %%
data_sorted = data.sort_values(by="age_years")
data_sorted.head()
# Out:
#          checking_account  duration_months  \
# 391  0 <= ... <  102 euro               12
# 633   No checking account                9
# 296   No checking account               12
# 905         ... <  0 euro               12
# 495         ... <  0 euro               24
#
#                                credit_history              purpose  \
# 391  existing credits paid back duly till now  furniture/equipment
# 633  existing credits paid back duly till now  furniture/equipment
# 296  existing credits paid back duly till now           car (used)
# 905  existing credits paid back duly till now     radio/television
# 495  existing credits paid back duly till now  furniture/equipment
#
#      credit_amount                      savings present_employment_since  \
# 391            983               .. >= 511 euro             ... < 1 year
# 633           1980               ... <  51 euro             ... < 1 year
# 296           4675  unknown/ no savings account             ... < 1 year
# ...

# %%
data_sorted.loc[391]
# Out:
# checking_account                                 0 <= ... <  102 euro
# duration_months                                                    12
# credit_history               existing credits paid back duly till now
# purpose                                           furniture/equipment
# credit_amount                                                     983
# savings                                                .. >= 511 euro
# present_employment_since                                 ... < 1 year
# installment_rate                                                    1
# personal_status_sex               female : divorced/separated/married
# other_deptors                                                    none
# present_residence                                                   4
# property                                                  real estate
# age_years                                                          19
# ...

# %%
data_sorted.iloc[0]
# Out:
# checking_account                                 0 <= ... <  102 euro
# duration_months                                                    12
# credit_history               existing credits paid back duly till now
# purpose                                           furniture/equipment
# credit_amount                                                     983
# savings                                                .. >= 511 euro
# present_employment_since                                 ... < 1 year
# installment_rate                                                    1
# personal_status_sex               female : divorced/separated/married
# other_deptors                                                    none
# present_residence                                                   4
# property                                                  real estate
# age_years                                                          19
# ...

# %%
data.iloc[10:20, [0, 3, 5]]
# Out:
# checking_account                  ... <  0 euro
# purpose                        radio/television
# savings             unknown/ no savings account
# Name: 0, dtype: object

# %%
columns = ['age_years', 'purpose', 'credit_amount']
data.iloc[50:100][columns]
# Out:
#     age_years              purpose  credit_amount
# 50         29  furniture/equipment           2333
# 51         30           car (used)           5965
# 52         25     radio/television           1262
# 53         31           car (used)           3378
# 54         57            car (new)           2225
# 55         26            car (new)            783
# 56         52     radio/television           6468
# 57         31     radio/television           9566
# 58         23            car (new)           1961
# 59         23  furniture/equipment           6229
# 60         27             business           1391
# 61         50     radio/television           1537
# 62         61             business           1953
# 63         25             business          14421
# 64         26     radio/television           3181
# 65         48              repairs           5190
# 66         29     radio/television           2171
# 67         22            car (new)           1007
# ...

# %%
# create an additional column
data['duration_type'] = np.where(data['duration_months'] > 12, "long", "short")
data['duration_type'].head()
# Out:
# 0    short
# 1     long
# 2    short
# 3     long
# 4     long
# Name: duration_type, dtype: object

# %%
data['purpose'].unique()
# Out:
# array(['radio/television', 'education', 'furniture/equipment',
#        'car (new)', 'car (used)', 'business', 'domestic appliances',
#        'repairs', 'others', 'retraining'], dtype=object)

# %%
data['purpose'].value_counts()
# Out:
# purpose
# radio/television       280
# car (new)              234
# furniture/equipment    181
# car (used)             103
# business                97
# education               50
# repairs                 22
# domestic appliances     12
# others                  12
# retraining               9
# Name: count, dtype: int64

# %%
# filter method 1
data[data['age_years'] > 60].head()
# Out:
#         checking_account  duration_months  \
# 0          ... <  0 euro                6
# 8    No checking account               12
# 29         ... <  0 euro               60
# 62  0 <= ... <  102 euro               36
# 75         ... <  0 euro               12
#
#                                        credit_history           purpose  \
# 0   critical account/other credits existing (not a...  radio/television
# 8            existing credits paid back duly till now  radio/television
# 29                    delay in paying off in the past          business
# 62       no credits taken/ all credits paid back duly          business
# 75  critical account/other credits existing (not a...        car (used)
#
#     credit_amount                      savings present_employment_since  \
# 0            1169  unknown/ no savings account            .. >= 7 years
# 8            3059               .. >= 511 euro      4  <= ... < 7 years
# ...

# %%
# using 'query'
data.query("age_years > 60")
# Out:
#          checking_account  duration_months  \
# 0           ... <  0 euro                6
# 8     No checking account               12
# 29          ... <  0 euro               60
# 62   0 <= ... <  102 euro               36
# 75          ... <  0 euro               12
# 96    No checking account               12
# 123           >= 102 euro               10
# 137  0 <= ... <  102 euro               12
# 163  0 <= ... <  102 euro               10
# 179         ... <  0 euro               21
# 186  0 <= ... <  102 euro                9
# 187  0 <= ... <  102 euro               16
# 213           >= 102 euro               30
# 219   No checking account               10
# 237  0 <= ... <  102 euro               21
# 283   No checking account               15
# 330         ... <  0 euro               24
# 360  0 <= ... <  102 euro               18
# 373   No checking account               60
# 430   No checking account                5
# 438         ... <  0 euro               42
# ...

# %%
data.query("age_years > 60 & duration_months < 30")
# Out:
#          checking_account  duration_months  \
# 0           ... <  0 euro                6
# 8     No checking account               12
# 75          ... <  0 euro               12
# 96    No checking account               12
# 123           >= 102 euro               10
# 137  0 <= ... <  102 euro               12
# 163  0 <= ... <  102 euro               10
# 179         ... <  0 euro               21
# 186  0 <= ... <  102 euro                9
# 187  0 <= ... <  102 euro               16
# 219   No checking account               10
# 237  0 <= ... <  102 euro               21
# 283   No checking account               15
# 330         ... <  0 euro               24
# 360  0 <= ... <  102 euro               18
# 430   No checking account                5
# 449  0 <= ... <  102 euro               15
# 465         ... <  0 euro               24
# 487   No checking account               24
# 536         ... <  0 euro                6
# 544   No checking account               12
# ...

# %%
# 
data['purpose'].unique()
# Out:
# array(['radio/television', 'education', 'furniture/equipment',
#        'car (new)', 'car (used)', 'business', 'domestic appliances',
#        'repairs', 'others', 'retraining'], dtype=object)

# %%
selected_purposes = ['car (new)', 'car (used)']

data.query("purpose == @selected_purposes").head()
# Out:
#         checking_account  duration_months  \
# 4          ... <  0 euro               24
# 7   0 <= ... <  102 euro               36
# 9   0 <= ... <  102 euro               30
# 10  0 <= ... <  102 euro               12
# 13         ... <  0 euro               24
#
#                                        credit_history     purpose  \
# 4                     delay in paying off in the past   car (new)
# 7            existing credits paid back duly till now  car (used)
# 9   critical account/other credits existing (not a...   car (new)
# 10           existing credits paid back duly till now   car (new)
# 13  critical account/other credits existing (not a...   car (new)
#
#     credit_amount         savings present_employment_since  installment_rate  \
# 4            4870  ... <  51 euro      1  <= ... < 4 years                 3
# 7            6948  ... <  51 euro      1  <= ... < 4 years                 2
# ...

# %%
# pattern matching
data.query("purpose.str.contains('bus')")
# Out:
#          checking_account  duration_months  \
# 11          ... <  0 euro               48
# 17          ... <  0 euro               30
# 29          ... <  0 euro               60
# 30   0 <= ... <  102 euro               18
# 33    No checking account               12
# ..                    ...              ...
# 951         ... <  0 euro               36
# 973         ... <  0 euro               60
# 977  0 <= ... <  102 euro               18
# 981   No checking account               48
# 986           >= 102 euro               42
#
#                                         credit_history   purpose  \
# 11            existing credits paid back duly till now  business
# 17        no credits taken/ all credits paid back duly  business
# 29                     delay in paying off in the past  business
# 30            existing credits paid back duly till now  business
# 33   critical account/other credits existing (not a...  business
# ...

# %%
selected_columns = ['purpose', 'credit_amount', 'age_years', 'duration_months']

data_grouped = (
    data[selected_columns]
    .groupby('purpose')
    .agg({
        'credit_amount': 'sum',
        'age_years': 'mean',
        'duration_months': 'max'
    })
    .assign(age_years = lambda x: x['age_years'].round())
    .rename(columns={
        'credit_amount': 'Credit Amount',
        'age_years': 'mean_age_years',
        'duration_months': 'max_duration_months'
    })
    .sort_values("mean_age_years", ascending=False)
    .reset_index()
    

)

data_grouped
# Out:
#                purpose  Credit Amount  mean_age_years  max_duration_months
# 0               others          98512            40.0                   60
# 1            education         159020            39.0                   60
# 2              repairs          60018            39.0                   42
# 3            car (new)         716748            37.0                   60
# 4           car (used)         553133            37.0                   54
# 5             business         403330            35.0                   60
# 6     radio/television         696543            35.0                   72
# 7           retraining          10853            35.0                   24
# 8  domestic appliances          17976            34.0                   48
# 9  furniture/equipment         555125            32.0                   48

# %%
data_grouped.to_csv("data/export/loan_purposes.csv", index=False)

# %%
# export to excel
with pd.ExcelWriter('data/export/loans.xlsx') as writer:  
    # overview loans
    data.to_excel(writer,
                  sheet_name="Overview",)

    # loan purposes
    data_grouped.to_excel(writer, 
                          sheet_name="Loan Purposes")
